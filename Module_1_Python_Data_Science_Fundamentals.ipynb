# %%
print("Module 1 - Python & Data Science Fundamentals")
print("Name: Iqra")
print("Field: BS Data Science")
# Out:
# Module 1 - Python & Data Science Fundamentals
# Name: Iqra
# Field: BS Data Science

# %%
name = "Iqra"
age = 20
marks = 76
cgpa = 3.64
is_student = True

print("Name:", name)
print("Age:", age)
print("Marks:", marks)
print("CGPA:", cgpa)
print("Student:", is_student)
# Out:
# Name: Iqra
# Age: 20
# Marks: 76
# CGPA: 3.64
# Student: True

# %%
print(type(name))
print(type(age))
print(type(marks))
print(type(cgpa))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
a = 20
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Remainder:", a % b)
# Out:
# Addition: 25
# Subtraction: 15
# Multiplication: 100
# Division: 4.0
# Remainder: 0

# %%
marks = 76

if marks >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
number = 1

while number <= 5:
    print(number)
    number = number + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
marks = [89, 79, 69, 90, 70]

print("Marks:", marks)
print("First mark:", marks[0])
print("Last mark:", marks[-1])
print("Total marks:", len(marks))
# Out:
# Marks: [89, 79, 69, 90, 70]
# First mark: 89
# Last mark: 70
# Total marks: 5

# %%
for mark in marks:
    print(mark)
# Out:
# 89
# 79
# 69
# 90
# 70

# %%
marks.append(92)

print("Updated marks:", marks)
# Out:
# Updated marks: [89, 79, 69, 90, 70, 92]

# %%
student = {
    "name": "Iqra",
    "age": 20,
    "field": "Data Science",
    "marks": 76
}

print(student)
print("Name:", student["name"])
print("Field:", student["field"])
print("Marks:", student["marks"])
# Out:
# {'name': 'Iqra', 'age': 20, 'field': 'Data Science', 'marks': 76}
# Name: Iqra
# Field: Data Science
# Marks: 76

# %%
for key, value in student.items():
    print(key, ":", value)
# Out:
# name : Iqra
# age : 20
# field : Data Science
# marks : 76

# %%
def greet(name):
    print("Hello", name)
    print("Welcome to Data Science!")

greet("Iqra")
# Out:
# Hello Iqra
# Welcome to Data Science!

# %%
def calculate_average(a, b, c):
    average = (a + b + c) / 3
    return average

result = calculate_average(70, 80, 90)

print("Average:", result)
# Out:
# Average: 80.0

# %%
file = open("students.txt", "w")

file.write("Iqra, 76\n")
file.write("Ali, 82\n")
file.write("Sara, 91\n")

file.close()

print("File created successfully!")
# Out:
# File created successfully!

# %%
file = open("students.txt", "r")

data = file.read()

print(data)

file.close()
# Out:
# Iqra, 76
# Ali, 82
# Sara, 91

# %% [markdown]
# # Introduction to Data Science
#
# Data Science is a field that uses data, programming, statistics, and machine learning to extract useful information and solve real-world problems.
#
# ## Applications of Data Science
#
# 1. Healthcare
# 2. Banking
# 3. E-commerce
# 4. Education
# 5. Marketing
#
# ## Important Concepts
#
# - Data Analysis
# - Data Visualization
# - Machine Learning
# - Artificial Intelligence
# - Statistics
# - Python Programming

# %%
students = {
    "Iqra": 76,
    "Ali": 82,
    "Sara": 91,
    "Ahmed": 68
}

for name, marks in students.items():
    print(name, ":", marks)
# Out:
# Iqra : 76
# Ali : 82
# Sara : 91
# Ahmed : 68

# %%
marks = list(students.values())

average = sum(marks) / len(marks)

print("Average Marks:", average)
# Out:
# Average Marks: 79.25

# %%
students = [
    {"name": "Iqra", "marks": 76},
    {"name": "Ali", "marks": 82},
    {"name": "Sara", "marks": 91},
    {"name": "Ahmed", "marks": 68}
]

total = 0

for student in students:
    print(student["name"], "-", student["marks"])
    total = total + student["marks"]

average = total / len(students)

print("Average Marks:", average)
# Out:
# Iqra - 76
# Ali - 82
# Sara - 91
# Ahmed - 68
# Average Marks: 79.25
